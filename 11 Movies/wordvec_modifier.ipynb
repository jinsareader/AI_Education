# %%
import numpy
import custom
import pickle

# %%
with open("data/model.txt", mode = "r") as f:
    original_data = f.read()

# %%
data = original_data.replace("_"," ")
data = data.split("\n")

vec_dict = {}
line_len = len(data[1].split())
vec_dict["<pad>"] = list(numpy.zeros(shape = (line_len - 2)))
vec_dict["<unk>"] = list(numpy.zeros(shape = (line_len - 2)))

for i in range(1,len(data)) :
    vec = []
    line = data[i].split()
    if len(line) != line_len : #벡터 길이 맞지 않으면 넘김
        continue
    word = custom.text_preprocess(line[0]).replace(" ","").replace("N","")
    if word in vec_dict : #빈 단어면 넘김 or 이미 있는 단어면 넘김
        continue
    for j in range(2,len(line)) :
        vec.append(float(line[j]))
    vec_dict[word] = vec

print(len(vec_dict))
# Out:
# 123428

# %%
print(vec_dict["'t"])
# Out:
# [-0.037955407, -0.27807504, -0.2075363, 0.21083502, -0.35727143, -0.43805224, -0.07703038, -0.17685725, -0.45453295, -0.3415173, -0.279231, 0.21381931, -0.0013046324, 0.22872059, 0.0665821, -0.44996792, -0.13650079, -0.06709795, 0.58922374, 0.52008736, -0.48893422, 0.2083254, -0.2964385, -0.26831955, 0.16263506, -0.09924649, 0.027227016, 0.27253807, 0.078333415, 0.057332054, -0.05977375, 0.29261273, -0.25448462, -0.20201282, -0.02411342, -0.16595055, 0.13765237, -0.032846652, 0.11355229, 0.13847046, -0.428974, 0.11902625, -0.29572865, 0.10198483, -0.017275946, 0.21882923, 0.21601497, -0.4823778, -0.20800282, -0.13748528, 0.22665139, -0.30249655, 0.14029558, -0.2656665, 0.123610444, 0.089785844, 0.32150713, -0.023125263, 0.093177035, -0.15636016, -0.08071752, 0.0066814045, -0.18758065, -0.042614408, -0.24864814, -0.052548908, 0.06328589, 0.56402475, -0.053234, -0.06586414, 0.08749704, 0.41573638, -0.36901134, -0.21619123, 0.07052671, 0.1536901, -0.084553264, -0.10280274, 0.021404255, -0.22489245, 0.0043882746, 0.07258708, 0.26360098, -0.038976107, 0.24634132, -0.26411766, 0.04533277, -0.15091069, 0.17409906, -0.05590488, 0.059575528, -0.33843914, -0.0869003, 0.14109328, -0.2322303, -0.16982746, -0.12593159, -0.008624376, 0.39909175, -0.022017399, 0.1886198, 0.18170938, 0.25697783, -0.20905016, -0.114595376, 0.11135298, 0.18297954, -0.08055794, 0.06468319, -0.14297241, -0.58651805, 0.07648004, 0.7026151, 0.0042313207, -0.015927397, -0.16970554, -0.25761348, -0.099929474, 0.2698776, 0.15087792, 0.5813199, 0.6246935, 0.3130705, 0.10154086, -0.