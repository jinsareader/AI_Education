# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(''), '..'))

import numpy
import custom
import pickle

# %%
with open("data/model.txt", mode = "r") as f:
    original_data = f.read()

# %%
data = original_data.replace("_"," ")
data = data.split("\n")

vec_dict = {}
line_len = len(data[1].split())
vec_dict["<pad>"] = list(numpy.zeros(shape = (line_len - 2)))
vec_dict["<unk>"] = list(numpy.zeros(shape = (line_len - 2)))

for i in range(1,len(data)) :
    vec = []
    line = data[i].split()
    if len(line) != line_len : #벡터 길이 맞지 않으면 넘김
        continue
    word = custom.text_preprocess(line[0]).replace(" ","").replace("N","")
    if word in vec_dict : #빈 단어면 넘김 or 이미 있는 단어면 넘김
        continue
    for j in range(2,len(line)) :
        vec.append(float(line[j]))
    vec_dict[word] = vec

print(len(vec_dict))
# Out:
# 123281

# %%
print(vec_dict["t"])
# Out:
# [0.23999293, 0.48333976, -0.5665111, 0.11562427, -0.37017143, 0.26023972, -0.22483125, -0.27668634, 0.083253786, 0.13567199, -0.44930717, 0.6560129, -0.32415918, 0.04072213, -0.27281034, -0.2738325, -0.4005197, -0.07492834, 0.020503797, -0.57427436, 0.2552539, -0.5403996, 0.039085157, -0.33001268, -0.061297495, -0.17042837, 0.050034013, -0.11288076, 0.108171366, 0.28735697, -0.08909804, 0.038689986, 0.3351571, 0.13602492, 0.028146628, -0.112244025, -0.34182674, 0.16561005, -0.10474934, -0.11874844, 0.15631633, -0.07418516, 0.2721186, 0.22902332, 0.021747053, 0.36268955, 0.33740923, -0.2920172, -0.010996331, 0.23609276, -0.32246107, -0.058844473, -0.30017564, -0.19710639, 0.12864985, -0.04335033, -0.061456114, -0.20965111, 0.11091088, -0.18072195, 0.19658323, 0.41205752, 0.3782865, 0.085589476, 0.11685222, 0.21887772, -0.317873, 0.3367988, 0.19150728, -0.06123567, 0.359473, -0.39730534, 0.055909738, -0.12525241, -0.3021741, -0.09077508, -0.06851159, -0.08007267, -0.036488045, 0.02233704, 0.0364062, -0.2101731, -0.13803379, -0.26309663, 0.09372007, 0.64562434, 0.4041801, -0.2601101, -0.09763664, 0.056430165, -0.012465459, -0.008272894, 0.18166617, 0.079824634, 0.15881039, 0.38248983, -0.18127294, 0.19448428, -0.16525654, 0.2302549, 0.42598417, -0.029082106, -0.08140978, 0.04337675, -0.45690215, -0.6117435, -0.2624128, 0.23808499, -0.066964515, 0.16647674, -0.59280527, -0.05633624, 0.2691394, 0.07536495, -0.34545863, -0.1731222, -0.26117688, 0.20316577, -0.10635569, -0.35471684, -0.22272734, 0.25446633, 